# %% [markdown]
# #**🏆** Mini Challenge: Data Cleanup - Tweet Dataset (Darija)

# %% [markdown]
# 📌 Challenge Description:
#
# In this challenge, you will clean a tweet dataset from Hugging Face (`shmuhammad/AfriSenti-twitter-sentiment`), focusing on the Moroccan Darija subset. The goal is to preprocess the text data by removing emojis, usernames, and applying [texte du lien](https://)a custom list of Darija stop words. The cleaned data will then be ready for n-gram analysis.

# %% [markdown]
# 📊 Dataset Summary:
# AfriSenti is the largest sentiment analysis dataset for under-represented African languages, covering 110,000+ annotated tweets in 14 African languages (Amharic, Algerian Arabic, Hausa, Igbo, Kinyarwanda, Moroccan Arabic, Mozambican Portuguese, Nigerian Pidgin, Oromo, Swahili, Tigrinya, Twi, Xitsonga, and Yoruba).

# %% [markdown]
# # Part 1: Data Cleaning

# %%
#Installing Necessary Packages
# !pip install datasets pandas regex
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in c:\users\lenovo\appdata\roaming\python\python312\site-packages (3.6.0)
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\roaming\python\python312\site-packages (2.3.1)
# Requirement already satisfied: regex in c:\users\lenovo\appdata\roaming\python\python312\site-packages (2026.2.28)
# Requirement already satisfied: filelock in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (3.25.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (2.3.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (2.33.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (1.6.0)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.24.0->datasets) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.24.0->datasets) (0.28.1)
# Requirement already satisfied: typer in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.24.0->datasets) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: anyio in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24.0->datasets) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub>=0.24.0->datasets) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub>=0.24.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub>=0.24.0->datasets) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from typer->huggingface-hub>=0.24.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.24.0->datasets) (0.1.2)
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -q "datasets<4.0.0" pandas regex
# Out:
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Import Necessary Packages
from  datasets  import load_dataset
import pandas as pd
import re

# %% [markdown]
# ## Load the Dataset

# %%
import requests

# Télécharger le fichier .txt depuis GitHub
url = "https://raw.githubusercontent.com/zerouani/darija-stop-words/main/stopwords.txt"
response = requests.get(url)

# Sauvegarder en .csv 
with open("darija_stop_words.csv", "w", encoding="utf-8") as f:
    f.write("word\n")             
    f.write(response.text)         

print(" Fichier darija_stop_words.csv créé avec succès")
# Out:
#  Fichier darija_stop_words.csv créé avec succès

# %%
"""
Load the `shmuhammad/AfriSenti-twitter-sentiment` dataset from the Hugging Face `datasets` library for Moroccan Darija.
"""
darija_stop_words_df = pd.read_csv("./darija_stop_words.csv")
darija_stop_words = darija_stop_words_df['word'].tolist()

# %%
# dataset tweets darija
darija_dataset = load_dataset("shmuhammad/AfriSenti-twitter-sentiment", "ary", trust_remote_code=True)

# %%
""" Identify and select the subset of tweets of the train datasets"""
darija_dataset_df = pd.DataFrame(darija_dataset['train'])

# %% [markdown]
# ## Remove Emojis From Tweets

# %%
def remove_emojis(tweet):
    emoj = re.compile("["
       u"\U0001F600-\U0001F64F"  # emoticons
       u"\U0001F300-\U0001F5FF"  # symbols & pictographs
       u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                      u"\U0001F923"
                      u"\U0001F97A"
                      u"\U0001F914""]+", re.UNICODE)
    return re.sub(emoj ,'', tweet)

# %% [markdown]
# You can use this ressource emojis unicode: https://apps.timwhitlock.info/emoji/tables/unicode

# %%
# remove the emojis from the dataset
darija_dataset_df['tweet'] = darija_dataset_df['tweet'].apply(remove_emojis)

# %%
darija_dataset_df.head()
# Out:
#                                                tweet  label
# 0  hhhhhhhhhhhhhhhhhhhhhh ana ga3ma sma3tt ach ka...      1
# 1  hhhh hardart jomhorha la fi3lan kadahko lach m...      1
# 2  : أتفهم العثماني وأتفهم الجدل الشعبي. الحل: حا...      1
# 3                                كان افظل حاكم عربي'      0
# 4  ماريانو راخوي : خاص المغرب واسبانيا يشرحو للرأ...      1

# %% [markdown]
# ## Remove user name from tweets

# %%
def remove_user(tweet):
    user_re =  "@[A-Za-z0-9]+"
    return re.sub(user_re, ' ', tweet)

# %%
#remove the user names from the dataset
darija_dataset_df['tweet'] = darija_dataset_df['tweet'].apply(remove_user)

# %%
darija_dataset_df.sample(10)
darija_dataset_df.info
# Out:
# <bound method DataFrame.info of                                                   tweet  label
# 0     hhhhhhhhhhhhhhhhhhhhhh ana ga3ma sma3tt ach ka...      1
# 1     hhhh hardart jomhorha la fi3lan kadahko lach m...      1
# 2     : أتفهم العثماني وأتفهم الجدل الشعبي. الحل: حا...      1
# 3                                   كان افظل حاكم عربي'      0
# 4     ماريانو راخوي : خاص المغرب واسبانيا يشرحو للرأ...      1
# ...                                                 ...    ...
# 5578            wah akhouya titiz o dikchi 3la 9ad lhal      1
# 5579  soukaina dik nhar drt follow haydato o 9lt f k...      1
# 5580                kiban liya stormy kid7ak mn hna ana      1
# 5581            woww ghadi tefra7 bzzf thank uu aaliaaa      0
# 5582  الواقع وهوأن هؤلاء دخلوا مستنقعا لن يخرجوا منه...      2
#
# [5583 rows x 2 columns]>

# %% [markdown]
# ## Remove latin letter

# %%
def remove_latin(tweet):
    latin_re =  "[A-Za-z]+"
    return re.sub(latin_re, ' ', tweet)

# %%
#remove latin words
darija_dataset_df['tweet'] = darija_dataset_df['tweet'].apply(remove_latin)

# %% [markdown]
# ## Removing Dublicate Rows

# %%
darija_dataset_df.drop_duplicates(inplace = True)
darija_dataset_df
# Out:
#                                                   tweet  label
# 0                          3   3       9       3             1
# 1                 3         3              3                 1
# 2     : أتفهم العثماني وأتفهم الجدل الشعبي. الحل: حا...      1
# 3                                   كان افظل حاكم عربي'      0
# 4     ماريانو راخوي : خاص المغرب واسبانيا يشرحو للرأ...      1
# ...                                                 ...    ...
# 5578                                            3  9         1
# 5579                                         9               1
# 5580                                           7             1
# 5581                                          7              0
# 5582  الواقع وهوأن هؤلاء دخلوا مستنقعا لن يخرجوا منه...      2
#
# [5168 rows x 2 columns]

# %% [markdown]
# ## Remove Punctuation

# %%
import re
def remove_ponct(tweet):
    ponct_re =  "[^\w\s]+"
    return re.sub(ponct_re, ' ', tweet)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23640\878315859.py:3: SyntaxWarning: invalid escape sequence '\w'
#   ponct_re =  "[^\w\s]+"

# %%
#remove ponctuation
darija_dataset_df['tweet'] = darija_dataset_df['tweet'].apply(remove_ponct)

# %% [markdown]
# ## Tokenization

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
def Tokenize(tweet):
    return word_tokenize(tweet)

darija_dataset_df["tweet_token"] = darija_dataset_df['tweet'].apply(Tokenize)
darija_dataset_df.head()
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                                tweet  label  \
# 0                       3   3       9       3             1
# 1              3         3              3                 1
# 2    أتفهم العثماني وأتفهم الجدل الشعبي  الحل  حا...      1
# 3                                كان افظل حاكم عربي       0
# 4  ماريانو راخوي   خاص المغرب واسبانيا يشرحو للرأ...      1
#
#                                          tweet_token
# 0                                       [3, 3, 9, 3]
# 1                                          [3, 3, 3]
# 2  [أتفهم, العثماني, وأتفهم, الجدل, الشعبي, الحل,...
# 3                            [كان, افظل, حاكم, عربي]
# 4  [ماريانو, راخوي, خاص, المغرب, واسبانيا, يشرحو,...

# %% [markdown]
# ## Remove Stops Words

# %%
#Import darija stopwords dataset
# the darija stop words will be found here https://github.com/zerouani/darija-stop-words/blob/main/stopwords.txt, change the extension and the head name
darija_stop_words_df = pd.read_csv("./darija_stop_words.csv")
darija_stop_words = darija_stop_words_df['word'].tolist()

# %%
def remove_stop(all_tokens, stop_lst):
    stop_lst = {stp_wrd.strip() for stp_wrd in stop_lst}  # Convert stop_lst to a set for faster lookups
    return [token.strip() for token in all_tokens if token.strip() not in stop_lst]

# %%
#remove darija stopwords
darija_dataset_df['tweet_token'] = darija_dataset_df['tweet_token'].apply(remove_stop, args=(darija_stop_words,),)

# %%
all_token = [token for list_token in darija_dataset_df['tweet_token'] for token in list_token]

# %% [markdown]
# # Part 2: N-Grams Analysis

# %%
#Install Necessary Librairies
# !pip install nltk pandas matplotlib seaborn wordcloud networkx arabic-reshaper python-bidi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\lenovo\appdata\roaming\python\python312\site-packages (3.9.4)
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\roaming\python\python312\site-packages (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\lenovo\appdata\roaming\python\python312\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\lenovo\appdata\roaming\python\python312\site-packages (0.13.2)
# Requirement already satisfied: wordcloud in c:\users\lenovo\appdata\roaming\python\python312\site-packages (1.9.6)
# Requirement already satisfied: networkx in c:\users\lenovo\appdata\roaming\python\python312\site-packages (3.6.1)
# Requirement already satisfied: arabic-reshaper in c:\users\lenovo\appdata\roaming\python\python312\site-packages (3.0.1)
# Requirement already satisfied: python-bidi in c:\users\lenovo\appdata\roaming\python\python312\site-packages (0.6.10)
# Requirement already satisfied: click in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from nltk) (8.3.2)
# Requirement already satisfied: joblib in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Unigrams

# %%
from collections import Counter
unigram_counts = Counter(all_token)

# %% [markdown]
# ## Barplot of Unigrams

# %%
#Import Necessary Packages
import matplotlib.pyplot as plt
import seaborn as sns
import arabic_reshaper
from bidi.algorithm import get_display

# %%
def plot_top_n_grams(ngram_counts, n, title):
    top_n = ngram_counts.most_common(n)
    words, counts = zip(*top_n)
    plt.figure(figsize=(12, 6))
    reshaped_words = [arabic_reshaper.reshape(word) for word in words]
    bidi_words = [get_display(word) for word in reshaped_words]
    sns.barplot(x=list(counts), y=bidi_words, palette="viridis")
    plt.title(f"Top {n} {title}")
    plt.xlabel("Frequency")
    plt.ylabel("N-gram")
    plt.show()

plot_top_n_grams(unigram_counts, 20, "Unigrams")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_23640\3839270694.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts), y=bidi_words, palette="viridis")
# C:\Users\Lenovo\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65010 (\N{ARABIC LIGATURE ALLAH ISOLATED FORM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## WordCloud

# %%
#Import Necessary Librairies
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# download the ttf file from this website: https://arbfonts.com/noto-naskh-arabic-regular-font-download.html
cloud_ar = WordCloud(font_path='NotoNaskhArabic-VariableFont_wght.ttf', background_color="white").generate_from_frequencies(unigram_counts)
plt.imshow(cloud_ar, interpolation='bilinear')
plt.axis('off')

plt.savefig("ary")
plt.show()
